# %% [markdown]
# <a href="https://colab.research.google.com/github/Mustas5/Hackathon-Mano-Mano/blob/main/October_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #1 - August

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Hackathon/Hackathon_2/2022-01 Wild Code School x ManoMano_ CES Data Set - August 2021 (1).csv', sep = ',')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17652 entries, 0 to 17651
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      17652 non-null  int64
#  1   comment                 3206 non-null   object
#  2   original_comment        3495 non-null   object
#  3   score                   17652 non-null  int64
#  4   data_scale              17652 non-null  object
#  5   data_source             17652 non-null  object
#  6   created_at              17652 non-null  object
#  7   date                    17652 non-null  object
#  8   day                     17652 non-null  object
#  9   month                   17652 non-null  object
#  10  is_mf                   17652 non-null  bool
#  11  device                  17652 non-null  object
#  12  family                  17651 non-null  object
#  13  is_b2b                  17644 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# id                            0
# comment                   14446
# original_comment          14157
# score                         0
# data_scale                    0
# data_source                   0
# created_at                    0
# date                          0
# day                           0
# month                         0
# is_mf                         0
# device                        0
# family                        1
# is_b2b                        8
# reason                    16977
# browser                       0
# category                      1
# language                      0
# platform                      0
# provider                      1
# first_order                   0
# nb_articles                   0
# csat_presales                 0
# shipping_fees                 0
# bv_transaction                0
# payment_method                0
# operating_system              0
# last_paid_channel           103
# has_presales_contact          0
# ...

# %%
### check unique() ###

for i in df:
  print(f'{i}\n',df[i].unique(),'\n')

# %%
### check value_counts() ###

for i in df:
  print(f'{i}\n',df[i].value_counts(dropna = False),'\n')

# %%
df.columns
# Out:
# Index(['id', 'comment', 'original_comment', 'score', 'data_scale',
#        'data_source', 'created_at', 'date', 'day', 'month', 'is_mf', 'device',
#        'family', 'is_b2b', 'reason', 'browser', 'category', 'language',
#        'platform', 'provider', 'first_order', 'nb_articles', 'csat_presales',
#        'shipping_fees', 'bv_transaction', 'payment_method', 'operating_system',
#        'last_paid_channel', 'has_presales_contact', 'shipping_fees_bucket',
#        'bv_transaction_bucket', 'has_manodvisor_contact', 'themes', 'tags'],
#       dtype='object')

# %%
### most scored family and shows id.count() ###

df_groupby = df.groupby('family').agg({'score':'mean', 'id':'count'})
df_groupby.sort_values(by='score', ascending = False)

# %%
df_groupby = df.groupby('family', as_index = False).agg({'bv_transaction':'mean', 'id':'nunique'})
df_groupby.sort_values(by='bv_transaction', ascending = False)

#### create extra columns '% Transaction" #####

df_groupby['% Transaction'] = df_groupby['bv_transaction']/sum(df_groupby['bv_transaction'])*100
# seg_up_sucess_total_final

#### create extra columns '% ID" #####

df_groupby['% ID'] = df_groupby['id']/sum(df_groupby['id'])*100

df_groupby

# %%
df.corr(method = 'pearson')

# %%
sns.heatmap(df.corr(method='pearson'))

# %% [markdown]
# # 2 - October

# %%
df_oct = pd.read_csv('/content/drive/MyDrive/Hackathon/Hackathon_2/2022-01 Wild Code School x ManoMano_ CES Data Set - October 2021.csv', sep = ',')

# %%
df_oct
# Out:
#               id comment original_comment  ...  has_manodvisor_contact themes tags
# 0      328349850     NaN              NaN  ...                   False    NaN  NaN
# 1      328353620     NaN              NaN  ...                   False    NaN  NaN
# 2      328346035     NaN              NaN  ...                   False    NaN  NaN
# 3      328354882     NaN              NaN  ...                   False    NaN  NaN
# 4      328345755     NaN              NaN  ...                   False    NaN  NaN
# ...          ...     ...              ...  ...                     ...    ...  ...
# 24658  349370127     NaN              NaN  ...                   False    NaN  NaN
# 24659  349377281     NaN              NaN  ...                   False    NaN  NaN
# 24660  349369593     NaN              NaN  ...                   False    NaN  NaN
# 24661  349375131     NaN              NaN  ...                   False    NaN  NaN
# ...

# %%
df_oct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24663 entries, 0 to 24662
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      24663 non-null  int64
#  1   comment                 2609 non-null   object
#  2   original_comment        2609 non-null   object
#  3   score                   24663 non-null  int64
#  4   data_scale              24663 non-null  object
#  5   data_source             24663 non-null  object
#  6   created_at              24663 non-null  object
#  7   date                    24663 non-null  object
#  8   day                     24663 non-null  object
#  9   month                   24663 non-null  object
#  10  is_mf                   24663 non-null  bool
#  11  device                  24663 non-null  object
#  12  family                  24663 non-null  object
#  13  is_b2b                  24637 non-null  object
# ...

# %%
# df_oct['created_at'] = pd.to_datetime(df_oct['created_at'])#.to_date()
# df_oct['date'] = pd.to_datetime(df_oct['date'])#format = '%Y-%m-%d')
# df_oct.info()

# %%
# df_oct['created_at'].dt.date.value_counts()

# %%
# from datetime import datetime, timezone
 
# # FUNCTION TO REMOVE TIMEZONE
# def remove_timezone(dt):
   
#     # HERE `dt` is a python datetime
#     # object that used .replace() method
#     return dt.replace(tzinfo=None)
 
# # APPLY THE ABOVE FUNCTION TO
# # REMOVE THE TIMEZONE INFORMATION
# # FROM EACH RECORD OF TIMESTAMP COLUMN IN DATAFRAME
# df_oct['created_at'] = df_oct['created_at'].apply(remove_timezone)
 
# # PRINT THE DATATYPE OF
# # EACH COLUMN AFTER MANIPULATION
# print(df_oct.dtypes)

# %%
df_oct
# Out:
#               id comment original_comment  ...  has_manodvisor_contact themes tags
# 0      328349850     NaN              NaN  ...                   False    NaN  NaN
# 1      328353620     NaN              NaN  ...                   False    NaN  NaN
# 2      328346035     NaN              NaN  ...                   False    NaN  NaN
# 3      328354882     NaN              NaN  ...                   False    NaN  NaN
# 4      328345755     NaN              NaN  ...                   False    NaN  NaN
# ...          ...     ...              ...  ...                     ...    ...  ...
# 24658  349370127     NaN              NaN  ...                   False    NaN  NaN
# 24659  349377281     NaN              NaN  ...                   False    NaN  NaN
# 24660  349369593     NaN              NaN  ...                   False    NaN  NaN
# 24661  349375131     NaN              NaN  ...                   False    NaN  NaN
# ...

# %%
df_oct.isna().sum()
# Out:
# id                                     0
# comment                            22054
# original_comment                   22054
# score                                  0
# data_scale                             0
# data_source                            0
# created_at                             0
# date                                   0
# month                                  0
# is_mf                                  0
# family                                 0
# is_b2b                                26
# reason                             23630
# browser                                0
# category                               0
# language                               0
# platform                               0
# provider                               0
# nb_articles                            0
# csat_presales                          0
# shipping_fees                          0
# bv_transaction                         0
# operating_system                       0
# ...

# %%
### check unique() ###

for i in df_oct:
  print(f'{i}\n',df_oct[i].unique(),'\n')
# Out:
# id
#  [328349850 328353620 328346035 ... 349369593 349375131 349376906]
#
# comment
#  [nan 'Requesting a mobile phone number for this order is FREEDOM!'
#  'Value for money' ... "Yes, it's relatively easy to place an order."
#  'Very easy and satisfying' 'You almost always have stock.']
#
# original_comment
#  [nan
#  'Eine Handynummer für diese Bestellung zu fordern ist eine FRECHHEIT! '
#  'Preis-leistung Top' ...
#  'Oui c’est relativement facile de passer commande'
#  'Muy fácil y satisfactoria' 'casi siempre teneis stock']
#
# score
#  [ 8  9 10  7  6  5  2  1  4  3  0]
#
# data_scale
#  ['NPS']
#
# data_source
#  ['Customer Effort Score']
#
# created_at
#  ['2021-10-01T00:01:36.000Z' '2021-10-01T00:15:23.000Z'
#  '2021-10-01T00:40:06.000Z' ... '2021-10-31T23:21:17.000Z'
#  '2021-10-31T23:30:52.000Z' '2021-10-31T23:46:45.000Z']
#
# date
#  ['2021-10-01' '2021-10-02' '2021-10-03' '2021-10-04' '2021-10-05'
#  '2021-10-06' '2021-10-07' '2021-10-08' '2021-10-09' '2021-10-10'
# ...

# %%
### check value_counts() ###

for i in df_oct:
  print(f'{i}\n',df_oct[i].value_counts(dropna = False),'\n')
# Out:
# id
#  331974655    1
# 345924236    1
# 340839052    1
# 340837005    1
# 340843150    1
#             ..
# 337071379    1
# 345928980    1
# 345931029    1
# 337069891    1
# 331974657    1
# Name: id, Length: 24663, dtype: int64
#
# comment
#  NaN                                                                                                     22054
# I couldn't easily find the products I was looking for.                                                     14
# I thought shipping costs were too expensive.                                                               13
# Simple and fast                                                                                            11
# Easy and fast                                                                                              10
#                                                                                                         ...
# ...

# %%
#### Sum "bv_transaction", count "id", sum "nb_articles" by "family" #####
#### New columns that have % and Avg ###

df_oct_groupby = df_oct.groupby('family', as_index = False).agg({'bv_transaction':'sum',
                                                                 'id':'count',
                                                                 'nb_articles':'sum'})

#### create extra columns '% Transaction" #####
df_oct_groupby['% Transaction'] = df_oct_groupby['bv_transaction']/sum(df_oct_groupby['bv_transaction'])*100
df_oct_groupby['Avg Transaction'] = df_oct_groupby['bv_transaction']/(df_oct_groupby['id'])

#### create extra columns '% ID" #####
df_oct_groupby['% ID'] = df_oct_groupby['id']/sum(df_oct_groupby['id'])*100

#### create extra columns '% Article" #####
df_oct_groupby['% Article'] = df_oct_groupby['nb_articles']/sum(df_oct_groupby['nb_articles'])*100

#### create extra columns 'Mean Article" #####
df_oct_groupby['Avg Article by ID'] = df_oct_groupby['nb_articles']/(df_oct_groupby['id'])


df_oct_groupby.sort_values(by='bv_transaction', ascending = False)
# Out:
#                     family  bv_transaction  ...  % Article  Avg Article by ID
# 7                Outillage       649199.11  ...  21.336706           1.413201
# 4           Jardin piscine       532914.21  ...  17.685603           1.268415
# 6     Mobilier d'intérieur       511529.17  ...  13.610874           1.225576
# 8      Plomberie chauffage       406380.94  ...  10.048153           1.376618
# 11       Salle de bain, WC       342906.95  ...   7.820310           1.386278
# 3              Electricité       178021.57  ...   7.786785           1.479444
# 5                Luminaire       130292.02  ...   6.378764           1.361744
# 9            Quincaillerie       107103.28  ...   6.759722           1.234279
# 1   Construction matériaux        78446.08  ...   2.118128           1.572398
# 2                  Cuisine        58567.22  ...   1.916982           1.202677
# 10   Revêtement sol et mur        50854.87  ...   2.432037           1.280899
# ...

# %%
#### Average "bv_transaction" and count "id" by "family" #####

# df_oct_groupby = df_oct.groupby('family', as_index = False).agg({'bv_transaction':'mean', 'nb_articles':'sum'})


# #### create extra columns '% Transaction" #####

# df_oct_groupby['% Transaction'] = df_oct_groupby['bv_transaction']/sum(df_oct_groupby['bv_transaction'])*100


# #### create extra columns '% ID" #####

# df_oct_groupby['% Articles'] = df_oct_groupby['nb_articles']/sum(df_oct_groupby['nb_articles'])*100

# df_oct_groupby.sort_values(by='bv_transaction', ascending = False)

# %%
# df_oct_groupby = df_oct.groupby('family', as_index = False).agg({'bv_transaction':'mean', 'nb_articles':'mean'})
# df_oct_groupby.sort_values(by='bv_transaction', ascending = False)

# #### create extra columns '% Transaction" #####

# df_oct_groupby['% Transaction'] = df_oct_groupby['bv_transaction']/sum(df_oct_groupby['bv_transaction'])*100
# # seg_up_sucess_total_final

# #### create extra columns '% ID" #####

# df_oct_groupby['% ID'] = df_oct_groupby['nb_articles']/sum(df_oct_groupby['nb_articles'])*100

# df_oct_groupby

# %%
df_oct.columns
# Out:
# Index(['id', 'comment', 'original_comment', 'score', 'data_scale',
#        'data_source', 'created_at', 'date', 'day', 'month', 'is_mf', 'device',
#        'family', 'is_b2b', 'reason', 'browser', 'category', 'language',
#        'platform', 'provider', 'first_order', 'nb_articles', 'csat_presales',
#        'shipping_fees', 'bv_transaction', 'payment_method', 'operating_system',
#        'last_paid_channel', 'has_presales_contact', 'shipping_fees_bucket',
#        'bv_transaction_bucket', 'has_manodvisor_contact', 'themes', 'tags'],
#       dtype='object')

# %%
df_oct_groupby = df_oct.groupby('score', as_index = False).agg({'shipping_fees':'mean', 'bv_transaction':'mean'})
df_oct_groupby.sort_values(by='score', ascending = False)

#### create extra columns '% Transaction" #####

# df_oct_groupby['% Transaction'] = df_oct_groupby['bv_transaction']/sum(df_oct_groupby['bv_transaction'])*100
# # seg_up_sucess_total_final

# #### create extra columns '% ID" #####

# df_oct_groupby['% ID'] = df_oct_groupby['nb_articles']/sum(df_oct_groupby['nb_articles'])*100

# df_oct_groupby
# Out:
#     score  shipping_fees  bv_transaction
# 10     10       4.884508      124.372267
# 9       9       5.330418      118.138293
# 8       8       5.912598      128.816122
# 7       7       5.903755      130.692560
# 6       6       5.428388      127.403967
# 5       5       6.328206      148.749899
# 4       4       7.547626      145.679281
# 3       3       6.767941      143.273603
# 2       2       4.860098      135.259412
# 1       1       5.847253      167.373516
# 0       0       5.604400      168.090267

# %%
df_oct_groupby = df_oct.groupby('is_mf', as_index = False).agg({'score':'mean', 'nb_articles':'mean'})
df_oct_groupby.sort_values(by='score', ascending = False)
# Out:
#    is_mf     score  nb_articles
# 0  False  8.961153     1.298741
# 1   True  8.914829     1.892776

# %%
df_oct.corr(method = 'pearson')
# Out:
#                               id  ...  has_manodvisor_contact
# id                      1.000000  ...               -0.001276
# score                  -0.005832  ...               -0.027749
# is_mf                  -0.003221  ...                0.002289
# first_order             0.000200  ...               -0.004904
# nb_articles             0.001349  ...                0.004415
# shipping_fees          -0.020678  ...                0.011861
# bv_transaction         -0.006837  ...                0.025506
# has_presales_contact    0.018127  ...                0.005317
# has_manodvisor_contact -0.001276  ...                1.000000
#
# [9 rows x 9 columns]

# %%
fig = plt.subplots(figsize=(10,8))

sns.heatmap(df_oct.corr(method='pearson'),
            annot = True, fmt = '.2g')

# %% [markdown]
# ###Get Dummies

# %%
df_oct = pd.get_dummies(df_oct, columns = ['day', 'device', 'payment_method', 'first_order', 'has_presales_contact'])

# %%
df_oct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24663 entries, 0 to 24662
# Data columns (total 51 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               24663 non-null  int64
#  1   comment                          2609 non-null   object
#  2   original_comment                 2609 non-null   object
#  3   score                            24663 non-null  int64
#  4   data_scale                       24663 non-null  object
#  5   data_source                      24663 non-null  object
#  6   created_at                       24663 non-null  object
#  7   date                             24663 non-null  object
#  8   month                            24663 non-null  object
#  9   is_mf                            24663 non-null  bool
#  10  family                           24663 non-null  object
#  11  is_b2b                           24637 non-null  object
# ...

# %%
fig = plt.subplots(figsize=(20,15))

sns.heatmap(df_oct.corr(method='pearson'),
            annot = True, fmt = '.2g')
